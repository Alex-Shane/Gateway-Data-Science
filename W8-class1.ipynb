# %% [markdown]
# # Finding the number of clusters

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn import metrics
from sklearn.metrics import pairwise_distances, silhouette_samples, silhouette_score

# %% [markdown]
# 1. Create a dataset of bloobs (using the `make_blobs` function) with $n=1000$ samples and use $k=4$ blobs. \\ Specify the blobs' centers at the points (1,1), (-1,1), (1,-1), (-1,-1) and with a std = 0.4 \\
# Finally, plot the data (using scatter)

# %%
n = 1000
blob_centers= ([1, 1], [-1, 1], [1,-1], [-1,-1])
X, y = make_blobs(n_samples=n, centers=blob_centers, cluster_std=0.4, random_state=0)
sns.scatterplot(x=X[:,0], y=X[:,1])
plt.show()

# %% [markdown]
# 2. For k = 1 to 10, create a k-means clustering models and compute inertia as a function of k.  Plot inertia vs k and see if you can identify an elbow. Write a for loop, if your model is `kmeans`, the method `kmeans.inertia_` outputs inertia for that model.

# %%
inertia = []
for k in range(1,10):
    kmeans = KMeans(n_clusters = k)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)
plt.plot(range(1,10), inertia)
# Out:
# /Users/Alex_1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/Alex_1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/Alex_1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# 3. Create silhouette plots for 2, 3, 4, and 5 clusters and visualize clusters

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)
y_predict = kmeans.fit_predict(X)
centroids = kmeans.cluster_centers_
silhouette_vals = silhouette_samples(X,y_predict)

y_ticks = []
y_lower = y_upper = 0
for i,cluster in enumerate(np.unique(y_predict)):
   cluster_silhouette_vals = silhouette_vals[y_predict == cluster]
   cluster_silhouette_vals.sort()
   y_upper += len(cluster_silhouette_vals)
   
   plt.barh(range(y_lower,y_upper),
   cluster_silhouette_vals,height =1);
   plt.text(-0.03,(y_lower+y_upper)/2,str(i+1))
   y_lower += len(cluster_silhouette_vals)
       
   # Get the average silhouette score 
   avg_score = np.mean(silhouette_vals)
   plt.axvline(avg_score,linestyle ='--',
   linewidth =2,color = 'green')
   plt.yticks([])
   plt.xlim([-0.1, 1])
   #plt.set_xlabel('Silhouette coefficient values')
   plt.ylabel('Cluster labels')
   plt.title('Silhouette plot for the various clusters');
# Out:
# /Users/Alex_1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/Alex_1/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
sns.scatterplot(x=X[:,0],y=X[:,1], hue=y_predict, palette=['orange','blue'])
plt.show()

# %% [markdown]
# 4. Create plot of silhouette score vs number of clusters. Use `metrics.silhouette_score(X, model.labels_, metric='euclidean')` if `model` is your k-means model.

# %%
silhoue = []
for k in range(2,10):
#
#

# %% [markdown]
#     5. Try out affinity propagation.  Plot the clusters using `seaborn` with `hue` set to `APmodel.fit_predict(X)`

# %%
from sklearn.cluster import AffinityPropagation

# %% [markdown]
# Print the cluster centers found by AP.

# %% [markdown]
# Reflect on finding the number of clusters from data.  Is it easy, hard, impossible?
